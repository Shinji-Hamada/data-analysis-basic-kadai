# %% [markdown]
# <a href="https://colab.research.google.com/github/Shinji-Hamada/data-analysis-basic-kadai/blob/main/kadai_007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('sample_pandas_6.csv')
df.head()
# Out:
#             発注日      商品番号              商品名   単価  在庫  注文数
# 131  2021-03-27  8T7D5DQA  商品サンプル 8T7D5DQA  120   0   42
# 199  2016-08-07  8T7D5DQA  商品サンプル 8T7D5DQA  120   0   42

# %%
import pandas as pd
df1=pd.read_csv('category.csv')
df1.head()
# Out:
#        商品番号  カテゴリー
# 0  YY4HAAZR     弁当
# 1  Z4WOOIYV    飲料水
# 2  1QJFO8QY     弁当
# 3  MESUDVWQ    菓子類
# 4  S6RE8W6X  図書・新聞

# %%
pip install japanize_matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 27.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for japanize_matplotlib: filename=japanize_matplotlib-1.1.3-py3-none-any.whl size=4120257 sha256=7e7a1f67c479a1131a567e031a4e19510df265a6b70a8a5406800844057b939f
#   Stored in directory: /root/.cache/pip/wheels/61/7a/6b/df1f79be9c59862525070e157e62b08eab8ece27c1b68fbb94
# Successfully built japanize_matplotlib
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import japanize_matplotlib

df = pd.merge(df, df1[['商品番号', 'カテゴリー']], how='inner', on='商品番号')
x = np.array([1, 2, 3, 4, 5,6])
y = np.array([49, 38, 36, 30, 27,20])
label = ["弁当", "菓子類" , "飲料水", "デザート", "雑貨","図書・新聞"]
plt.title("カテゴリー列のの出現頻度")
plt.bar(x, y, tick_label=label)
# Out:
# <BarContainer object of 6 artists>

# %%
df3=df.groupby('商品番号')['注文数'].sum()
df3.describe()
# Out:
# count      10.000000
# mean      619.800000
# std       264.439785
# min       216.000000
# 25%       531.000000
# 50%       588.000000
# 75%       724.500000
# max      1128.000000
# Name: 注文数, dtype: float64
